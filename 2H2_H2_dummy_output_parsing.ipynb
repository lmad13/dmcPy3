# %% [markdown]
# ## 2H2_H2_dummy_input_5.log and 2H2_H2_dummy_input_6.log Parsing

# %%
import sys
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
#print(F"The arguments are: string(sys.argv)")
#if len(sys.argv) < 3:
#    print("Uh Oh! You did not provide a command line argument that had the name of the file!")
#    exit()
#else:
#    fileName = sys.argv[1]
#    print(F'reading {filename}')

# %%
outputfile = os.path.join('2H2_H2_dummy_input_5.log')
outfile = open(outputfile, 'r')
data = outfile.readlines()
outfile.close()

# %%
lines = len(data)
print(lines, 'lines are in the file')
for line in data:
    if "SCF Done" in line:
        energy_line = line
        words = energy_line.split()
        energy = words[4]
        energy = float(energy)
        print(energy)
# Out:
# 40067 lines are in the file
# -153.076373366
# -153.076249441
# -153.07587572
# -153.075246346
# -153.074351492
# -153.073177261
# -153.071705551
# -153.069913873
# -153.067775128
# -153.065257342
# -153.062323351
# -153.058930446
# -153.055029974
# -153.050566897
# -153.045479338
# -153.039698104
# -153.033146256
# -153.025738729
# -153.017382103
# -153.07907831
# -153.078671144
# -153.078055036
# -153.077218874
# -153.076148334
# -153.074825689
# -153.073229577
# -153.071334755
# -153.069111807
# -153.066526818
# -153.063541017
# -153.060110377
# -153.056185171
# -153.051709513
# -153.046620858
# -153.040849509
# -153.034318147
# -153.026941432
# -153.018625729
# -153.083848099
# -153.083040355
# -153.08207816
# -153.080944794
# -153.07962104
# -153.078084921
# -153.076311419
# -153.074272162
# -153.071935088
# -153.069264073
# -153.066218521
# -153.062752935
# -153.058816431
# -153.054352239
# -153.049297173
# -153.043581092
# -153.037126387
# -153.029847517
# -153.021650658
# ...

# %%
import numpy

def PrintArraySCF(fileName):
    readFile = open(fileName, 'r')
    scflist = []
    for line in data:
        if "SCF Done" in line:
            energy_line = line
            words = energy_line.split()
            energy = words[4]
            energy = float(energy)
            scflist.append(energy)
    
    readFile.close()
    return np.array(scflist)

scfarray = PrintArraySCF('2H2_H2_dummy_input_5.log')
numberofscf = len(scfarray)
print(numberofscf)

def PrintArrayAxes(fileName):
    readFile = open(fileName, 'r')
    variablelist = []
    printThisLine = False
    for line in data:
        if 'Summary of the potential surface scan:' in line:
            printThisLine = True
        if printThisLine:
            listline = line.split()
            variablelist.append(listline[0])
    
    print(variablelist)
    readFile.close()
                  
PrintArrayAxes('2H2_H2_dummy_input_5.log')
# Out:
# 361
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-115-e61fd8767842> in <module>
#      33     readFile.close()
#      34
# ---> 35 PrintArrayAxes('2H2_H2_dummy_input_5.log')
#
# <ipython-input-115-e61fd8767842> in PrintArrayAxes(fileName)
#      28         if printThisLine:
#      29             listline = line.split()
# ---> 30             variablelist.append(listline[0])
#      31
#      32     print(variablelist)
#
# IndexError: list index out of range

# %%
import numpy as np
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt

def PrintArraySCF(fileName):
    readFile = open(fileName, 'r')
    scflist = []
    data = readFile
    for line in data:
        if "SCF Done" in line:
            energy_line = line
            words = energy_line.split()
            energy = words[4]
            energy = float(energy)
            scflist.append(energy)
    
    readFile.close()
    return np.array(scflist)

scfarray = PrintArraySCF('2H2_H2_dummy_input_5.log')

def PrintArrayb6(fileName):
    readFile = open(fileName, 'r')
    data = readFile
    variablelist = []
    printThisLine = False
    for line in data:
        if 'Summary of the potential surface scan:' in line:
            printThisLine = True
        if 'JKIM22' in line:
            printThisLine = False
        if printThisLine:
            listline = line.split()
            if len(listline) == 4:
                if len(listline[0]) < 4 & len(listline[1]) > 2:
                    b6 = float(listline[1])
                    variablelist.append(b6)
    
    readFile.close()
    return np.array(variablelist)
                  
b6array = PrintArrayb6('2H2_H2_dummy_input_5.log')

def PrintArraya5(fileName):
    readFile = open(fileName, 'r')
    data = readFile
    variablelist = []
    printThisLine = False
    for line in data:
        if 'Summary of the potential surface scan:' in line:
            printThisLine = True
        if 'JKIM22' in line:
            printThisLine = False
        if printThisLine:
            listline = line.split()
            if len(listline) == 4:
                if len(listline[0]) < 4 & len(listline[1]) > 2:
                    a5 = float(listline[2])
                    variablelist.append(a5)
    
    readFile.close()
    return np.array(variablelist)

a5array = PrintArraya5('2H2_H2_dummy_input_5.log')

x = b6array
y = a5array
z = scfarray

editedx = x-x[0]
editedy = y-y[0]

fig = plt.figure()
ax1 = fig.add_subplot(111, projection = '3d')
ax1.scatter(editedx, editedy, z, c=z, cmap='RdBu')
ax1.set_xlabel('B6 (Angstrom)')
ax1.set_ylabel('A5 (Degrees)')
ax1.set_zlabel('Energy (a.u.)')
ax1.set_title('2H2_H2_dummy_input_5.log')
plt.show()

print(x)
print(y)
print(z)
# Out:
# [2.3    2.2611 2.2222 2.1833 2.1444 2.1056 2.0667 2.0278 1.9889 1.95
#  1.9111 1.8722 1.8333 1.7944 1.7556 1.7167 1.6778 1.6389 1.6    2.3
#  2.2611 2.2222 2.1833 2.1444 2.1056 2.0667 2.0278 1.9889 1.95   1.9111
#  1.8722 1.8333 1.7944 1.7556 1.7167 1.6778 1.6389 1.6    2.3    2.2611
#  2.2222 2.1833 2.1444 2.1056 2.0667 2.0278 1.9889 1.95   1.9111 1.8722
#  1.8333 1.7944 1.7556 1.7167 1.6778 1.6389 1.6    2.3    2.2611 2.2222
#  2.1833 2.1444 2.1056 2.0667 2.0278 1.9889 1.95   1.9111 1.8722 1.8333
#  1.7944 1.7556 1.7167 1.6778 1.6389 1.6    2.3    2.2611 2.2222 2.1833
#  2.1444 2.1056 2.0667 2.0278 1.9889 1.95   1.9111 1.8722 1.8333 1.7944
#  1.7556 1.7167 1.6778 1.6389 1.6    2.3    2.2611 2.2222 2.1833 2.1444
#  2.1056 2.0667 2.0278 1.9889 1.95   1.9111 1.8722 1.8333 1.7944 1.7556
#  1.7167 1.6778 1.6389 1.6    2.3    2.2611 2.2222 2.1833 2.1444 2.1056
#  2.0667 2.0278 1.9889 1.95   1.9111 1.8722 1.8333 1.7944 1.7556 1.7167
# ...

# %%
import numpy as np
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt

def PrintArraySCF(fileName):
    readFile = open(fileName, 'r')
    scflist = []
    data = readFile
    for line in data:
        if "SCF Done" in line:
            energy_line = line
            words = energy_line.split()
            energy = words[4]
            energy = float(energy)
            scflist.append(energy)
    
    readFile.close()
    return np.array(scflist)

def PrintArrayb6(fileName):
    readFile = open(fileName, 'r')
    data = readFile
    variablelist = []
    printThisLine = False
    for line in data:
        if 'Summary of the potential surface scan:' in line:
            printThisLine = True
        if 'JKIM22' in line:
            printThisLine = False
        if printThisLine:
            listline = line.split()
            if len(listline) == 5:
                if len(listline[0]) < 6 & len(listline[1]) > 2:
                    b6 = float(listline[1])
                    variablelist.append(b6)
    
    readFile.close()
    return np.array(variablelist)

def PrintArraya6(fileName):
    readFile = open(fileName, 'r')
    data = readFile
    variablelist = []
    printThisLine = False
    for line in data:
        if 'Summary of the potential surface scan:' in line:
            printThisLine = True
        if 'JKIM22' in line:
            printThisLine = False
        if printThisLine:
            listline = line.split()
            if len(listline) == 5:
                if len(listline[0]) < 6 & len(listline[1]) > 2:
                    a5 = float(listline[2])
                    variablelist.append(a5)
    
    readFile.close()
    return np.array(variablelist)
                  
def PrintArraya7(fileName):
    readFile = open(fileName, 'r')
    data = readFile
    variablelist = []
    printThisLine = False
    for line in data:
        if 'Summary of the potential surface scan:' in line:
            printThisLine = True
        if 'JKIM22' in line:
            printThisLine = False
        if printThisLine:
            listline = line.split()
            if len(listline) == 5:
                if len(listline[0]) < 6 & len(listline[1]) > 2:
                    a5 = float(listline[3])
                    variablelist.append(a5)
    
    readFile.close()
    return np.array(variablelist)


x = PrintArrayb6('2H2_H2_dummy_input_3.log')
y = PrintArraya6('2H2_H2_dummy_input_3.log')
z = PrintArraySCF('2H2_H2_dummy_input_3.log')


fig = plt.figure()
ax1 = fig.add_subplot(111, projection = '3d')
ax1.scatter(x, y, z, c=z, cmap='RdBu')
ax1.set_xlabel('B6 (Angstrom)')
ax1.set_ylabel('A5 (Degrees)')
ax1.set_zlabel('Energy (a.u.)')
ax1.set_title('2H2_H2_dummy_input_3.log')
plt.show()

print(x)
print(y)
print(PrintArraya7('2H2_H2_dummy_input_3.log'))
print(z)
# Out:
# [2.3    2.2611 2.2222 2.1833 2.1444 2.1056 2.0667 2.0278 1.9889 1.95
#  2.3    2.2611 2.2222 2.1833 2.1444 2.1056 2.0667 2.0278 1.9889 1.95
#  2.3    2.2611 2.2222 2.1833 2.1444 2.1056 2.0667 2.0278 1.9889 1.95
#  2.3    2.2611 2.2222 2.1833 2.1444 2.1056 2.0667 2.0278 1.9889 1.95
#  2.3    2.2611 2.2222 2.1833 2.1444 2.1056 2.0667 2.0278 1.9889 1.95
#  2.3    2.2611 2.2222 2.1833 2.1444 2.1056 2.0667 2.0278 1.9889 1.95
#  2.3    2.2611 2.2222 2.1833 2.1444 2.1056 2.0667 2.0278 1.9889 1.95
#  2.3    2.2611 2.2222 2.1833 2.1444 2.1056 2.0667 2.0278 1.9889 1.95
#  2.3    2.2611 2.2222 2.1833 2.1444 2.1056 2.0667 2.0278 1.9889 1.95
#  2.3    2.2611 2.2222 2.1833 2.1444 2.1056 2.0667 2.0278 1.9889 1.95
#  2.3    2.2611 2.2222 2.1833 2.1444 2.1056 2.0667 2.0278 1.9889 1.95
#  2.3    2.2611 2.2222 2.1833 2.1444 2.1056 2.0667 2.0278 1.9889 1.95
#  2.3    2.2611 2.2222 2.1833 2.1444 2.1056 2.0667 2.0278 1.9889 1.95
#  2.3    2.2611 2.2222 2.1833 2.1444 2.1056 2.0667 2.0278 1.9889 1.95
# ...

# %%
import numpy as np
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt

def PrintArray(fileName):
    readFile = open(fileName, 'r')
    data = readFile
    b6 = []
    a6 = []
    a7 = []
    scf = []
    printThisLine = False
    for line in data:
        if 'Summary of the potential surface scan:' in line:
            printThisLine = True
        if 'JKIM22' in line:
            printThisLine = False
        if printThisLine:
            listline = line.split()
            if len(listline) == 5:
                if len(listline[0]) < 6 & len(listline[1]) > 2:
                    checka6 = 90 - float(listline[2])
                    checka7 = float(listline[3]) - 90
                    if checka6 == checka7:
                        b6.append(float(listline[1]))
                        a6.append(float(listline[2]))
                        a7.append(float(listline[3]))
                        scf.append(float(listline[4]))
    
    readFile.close()
    return np.array(b6), np.array(a6), np.array(a7), np.array(scf)

b6, a6, a7, scf = PrintArray("2H2_H2_dummy_input_3.log")
b62, a62, a72, scf2 = PrintArray("2H2_H2_dummy_input_3.log")

x = np.append(b6, b62)
y = np.append(a6, a62)
z = np.append(scf, scf2)

fig = plt.figure()
ax1 = fig.add_subplot(111, projection = '3d')
ax1.scatter(x, y, z, c=z, cmap='RdBu')
ax1.set_xlabel('B6 (Angstrom)')
ax1.set_ylabel('A5 (Degrees)')
ax1.set_zlabel('Energy (a.u.)')
ax1.set_title('2H2_H2_dummy_input_3.log and 2H2_H2_dummy_input_2.log')
plt.show()

# %%
import numpy as np
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt

def GetArrayVariable(fileName, variable):
    readFile = open(fileName, 'r')
    var = variable
    data = readFile
    variablelist = []
    printThisLine = False
    for line in data:
        if 'Summary of the potential surface scan:' in line:
            printThisLine = True
        if '-----------' in line:
            printThisLine = False
        if printThisLine:
            listline = line.split()
            if var in listline:
                index = listline.index(var)
            
            
    readFile.close()
    return index

GetArrayVariable("2H2_H2_dummy_input_3_trial.log", "A6")
# Out:
# 2
